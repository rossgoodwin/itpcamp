# %%
# Determining indefinite articles, pluralization, singularization

from pattern.en import referenced, pluralize, singularize

print referenced("university")
print referenced("hour")
print pluralize("child")
print singularize("wolves")

# Lots of other stuff is possible. Check out the documentation:
# http://www.clips.ua.ac.be/pages/pattern-en
# Out:
# a university
# an hour
# children
# wolf

# %%
# POS tagging and verb conjugation...
# Let's turn obituaries into bizarrely specific fortunes! (ala Sam Lavigne)

from pattern.en import conjugate, parsetree, FUTURE
from pattern.search import search, match
from pprint import pprint
import re

# %%
obitFile = open('obituary.txt', 'r')
obitText = obitFile.read().decode('utf-8').encode('ascii', 'ignore')
obitFile.close()

# regex to tokenize with spaces...
tokenCand = re.split(r"([^a-zA-Z0-9]{2,})|([^a-zA-Z0-9']+)", obitText)
tokens = filter(lambda x: x and x is not None, tokenCand)
print tokens


# Here's the POS tagset:
# http://www.clips.ua.ac.be/pages/mbsp-tags

s = parsetree(obitText)

# Navigating the parsetree...
for sentence in s:
    for chunk in sentence.chunks:
        print chunk.type, [(w.string, w.type) for w in chunk.words]
# Out:
# ['S', '. ', 'Parker', ' ', 'Gilbert', ', ', 'a', ' ', 'former', ' ', 'chairman', ' ', 'of', ' ', 'Morgan', ' ', 'Stanley', ' ', 'who', ' ', 'led', ' ', 'its', ' ', 'public', ' ', 'stock', ' ', 'offering', ' ', 'in', ' ', '1986', ' ', 'and', ' ', 'organized', ' ', 'a', ' ', 'management', ' ', 'revolt', ' ', 'at', ' ', 'that', ' ', 'storied', ' ', 'investment', ' ', 'house', ' ', '20', ' ', 'years', ' ', 'later', ', ', 'died', ' ', 'on', ' ', 'Wednesday', ' ', 'in', ' ', 'Manhattan', '. ', 'He', ' ', 'was', ' ', '81', '.\n\n', 'His', ' ', 'son', ' ', 'Parker', ' ', 'said', ' ', 'that', ' ', 'Mr', '. ', 'Gilbert', ' ', 'had', ' ', 'been', ' ', 'treated', ' ', 'for', ' ', 'chronic', ' ', 'obstructive', ' ', 'pulmonary', ' ', 'disease', ' ', 'for', ' ', 'years', ' ', 'and', ' ', 'that', ' ', 'he', ' ', 'died', ' ', 'at', ' ', 'NewYork', '-', 'Presbyterian', ' ', 'Hospital', '.\n\n', 'S', '. ', 'Parker', ' ', 'Gilbert', ' ', 'was', ' ', 'a', ' ', 'stepson', ' ', 'and', ' ', 'a', ' ', 'godson', ' ', 'of', ' ', 'Morgan', ' ', 'Stanleys', ' ', 'founders', ', ', 'and', ' ', 'he', ' ', 'came', ' ', 'of', ' ', 'age', ' ', 'on', ' ', 'Wall', ' ', 'Street', ' ', 'when', ' ', 'family', ' ', 'name', ' ', 'and', ' ', 'pedigree', ' ', 'were', ' ', 'often', ' ', 'enough', ' ', 'to', ' ', 'land', ' ', 'one', ' ', 'a', ' ', 'job', ' ', 'at', ' ', 'the', ' ', 'elite', ' ', 'partnerships', ' ', 'of', ' ', 'the', ' ', 'day', ', ', 'like', ' ', 'Morgan', ' ', 'Stanley', ' ', 'and', ' ', 'Goldman', ' ', 'Sachs', '.\n\n', 'But', ' ', 'he', ' ', 'also', ' ', 'played', ' ', 'a', ' ', 'role', ' ', 'in', ' ', 'exploding', ' ', 'this', ' ', 'cozy', ' ', 'world', ' ', 'when', ' ', 'he', ' ', 'united', ' ', 'a', ' ', 'divided', ' ', 'body', ' ', 'of', ' ', 'Morgan', ' ', 'Stanley', ' ', 'bankers', ' ', 'behind', ' ', 'the', ' ', 'idea', ' ', 'that', ' ', 'the', ' ', 'firm', ' ', 'could', ' ', 'grow', ' ', 'and', ' ', 'prosper', ' ', 'only', ' ', 'if', ' ', 'it', ' ', 'sold', ' ', 'shares', ' ', 'to', ' ', 'the', ' ', 'public', '.\n\n', 'That', ' ', 'move', ', ', 'and', ' ', 'the', ' ', 'subsequent', ' ', 'pressures', ' ', 'that', ' ', 'the', ' ', 'business', ' ', 'faced', ' ', 'as', ' ', 'a', ' ', 'public', ' ', 'company', ', ', 'led', ' ', 'to', ' ', 'Morgan', ' ', 'Stanleys', ' ', 'merger', ' ', 'in', ' ', '1997', ' ', 'with', ' ', 'the', ' ', 'retail', ' ', 'brokerage', ' ', 'firm', ' ', 'Dean', ' ', 'Witter', '.\n\n', 'And', ' ', 'when', ' ', 'Philip', ' ', 'J', '. ', 'Purcell', ', ', 'a', ' ', 'former', ' ', 'management', ' ', 'consultant', ' ', 'who', ' ', 'had', ' ', 'little', ' ', 'patience', ' ', 'for', ' ', 'the', ' ', 'egos', ' ', 'and', ' ', 'attitudes', ' ', 'of', ' ', 'the', ' ', 'companys', ' ', 'investment', ' ', 'bankers', ', ', 'took', ' ', 'swift', ' ', 'control', ' ', 'of', ' ', 'it', ', ', 'the', ' ', 'stage', ' ', 'was', ' ', 'set', ' ', 'for', ' ', 'Mr', '. ', 'Gilbert', '  ', 'who', ' ', 'was', ' ', 'then', ' ', 'deep', ' ', 'in', ' ', 'retirement', '  ', 'to', ' ', 'alter', ' ', 'his', ' ', 'companys', ' ', 'destiny', ' ', 'again', '.\n\n', 'In', ' ', '2005', ', ', 'he', ' ', 'lent', ' ', 'his', ' ', 'name', ', ', 'reputation', ' ', 'and', ' ', 'finances', ' ', 'to', ' ', 'a', ' ', 'searing', ' ', 'guerrilla', ' ', 'war', ' (', 'albeit', ' ', 'one', ' ', 'that', ' ', 'had', ' ', 'as', ' ', 'its', ' ', 'headquarters', ' ', 'the', ' ', 'study', ' ', 'in', ' ', 'his', ' ', 'Fifth', ' ', 'Avenue', ' ', 'apartment', ') ', 'that', ' ', 'eventually', ' ', 'forced', ' ', 'Mr', '. ', 'Purcell', ' ', 'from', ' ', 'power', ' ', 'on', ' ', 'the', ' ', 'assertion', ' ', 'that', ' ', 'his', ' ', 'more', ' ', 'conservative', ' ', 'financial', ' ', 'approach', ' ', 'was', ' ', 'ruining', ' ', 'Morgan', ' ', 'Stanleys', ' ', 'vaunted', ' ', 'culture', '.\n\n', 'Parker', ' ', 'was', ' ', 'the', ' ', 'heart', ' ', 'and', ' ', 'soul', ' ', 'of', ' ', 'Morgan', ' ', 'Stanley', ', ', 'said', ' ', 'Anson', ' ', 'M', '. ', 'Beard', ' ', 'Jr', '., ', 'a', ' ', ...
# NP [(u'S.', u'NNP'), (u'Parker', u'NNP'), (u'Gilbert', u'NNP')]
# NP [(u'a', u'DT'), (u'former', u'JJ'), (u'chairman', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP')]
# VP [(u'led', u'VBD')]
# NP [(u'its', u'PRP$'), (u'public', u'JJ'), (u'stock', u'NN'), (u'offering', u'NN')]
# PP [(u'in', u'IN')]
# VP [(u'organized', u'VBD')]
# NP [(u'a', u'DT'), (u'management', u'NN'), (u'revolt', u'NN')]
# PP [(u'at', u'IN')]
# NP [(u'that', u'DT'), (u'storied', u'JJ'), (u'investment', u'NN'), (u'house', u'NN')]
# NP [(u'20', u'CD'), (u'years', u'NNS')]
# ADVP [(u'later', u'RB')]
# VP [(u'died', u'VBD')]
# PP [(u'on', u'IN')]
# NP [(u'Wednesday', u'NNP')]
# PP [(u'in', u'IN')]
# NP [(u'Manhattan', u'NNP')]
# NP [(u'He', u'PRP')]
# VP [(u'was', u'VBD')]
# NP [(u'His', u'PRP$'), (u'son', u'NN'), (u'Parker', u'NNP')]
# VP [(u'said', u'VBD')]
# PP [(u'that', u'IN')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# VP [(u'had', u'VBD'), (u'been', u'VBN'), (u'treated', u'VBN')]
# PP [(u'for', u'IN')]
# NP [(u'chronic', u'JJ'), (u'obstructive', u'JJ'), (u'pulmonary', u'JJ'), (u'disease', u'NN')]
# PP [(u'for', u'IN')]
# NP [(u'years', u'NNS')]
# PP [(u'that', u'IN')]
# NP [(u'he', u'PRP')]
# VP [(u'died', u'VBD')]
# PP [(u'at', u'IN')]
# NP [(u'NewYork-Presbyterian', u'NNP'), (u'Hospital', u'NNP')]
# NP [(u'S.', u'NNP'), (u'Parker', u'NNP'), (u'Gilbert', u'NNP')]
# VP [(u'was', u'VBD')]
# NP [(u'a', u'DT'), (u'stepson', u'NN')]
# NP [(u'a', u'DT'), (u'godson', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'Morgan', u'NNP'), (u'Stanleys', u'NNP'), (u'founders', u'NNS')]
# NP [(u'he', u'PRP')]
# VP [(u'came', u'VBD')]
# PP [(u'of', u'IN')]
# NP [(u'age', u'NN')]
# PP [(u'on', u'IN')]
# NP [(u'Wall', u'NNP'), (u'Street', u'NNP')]
# NP [(u'family', u'NN'), (u'name', u'NN'), (u'and', u'CC'), (u'pedigree', u'NN')]
# VP [(u'were', u'VBD')]
# ADJP [(u'often', u'RB'), (u'enough', u'JJ')]
# NP [(u'land', u'NN'), (u'one', u'CD'), (u'a', u'DT'), (u'job', u'NN')]
# PP [(u'at', u'IN')]
# NP [(u'the', u'DT'), (u'elite', u'JJ'), (u'partnerships', u'NNS')]
# PP [(u'of', u'IN')]
# NP [(u'the', u'DT'), (u'day', u'NN')]
# PP [(u'like', u'IN')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP'), (u'and', u'CC'), (u'Goldman', u'NNP'), (u'Sachs', u'NNP')]
# NP [(u'he', u'PRP')]
# VP [(u'also', u'RB'), (u'played', u'VBD')]
# NP [(u'a', u'DT'), (u'role', u'NN')]
# PP [(u'in', u'IN')]
# VP [(u'exploding', u'VBG')]
# NP [(u'this', u'DT'), (u'cozy', u'JJ'), (u'world', u'NN')]
# NP [(u'he', u'PRP')]
# VP [(u'united', u'VBN')]
# VP [(u'divided', u'VBN')]
# NP [(u'body', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP'), (u'bankers', u'NNS')]
# PP [(u'behind', u'IN')]
# NP [(u'the', u'DT'), (u'idea', u'NN')]
# PP [(u'that', u'IN')]
# NP [(u'the', u'DT'), (u'firm', u'NN')]
# VP [(u'could', u'MD'), (u'grow', u'VB')]
# VP [(u'prosper', u'VB')]
# ADVP [(u'only', u'RB')]
# PP [(u'if', u'IN')]
# NP [(u'it', u'PRP')]
# VP [(u'sold', u'VBD')]
# NP [(u'shares', u'NNS')]
# NP [(u'the', u'DT'), (u'public', u'NN')]
# VP [(u'move', u'VBP')]
# NP [(u'the', u'DT'), (u'subsequent', u'JJ'), (u'pressures', u'NNS')]
# PP [(u'that', u'IN')]
# NP [(u'the', u'DT'), (u'business', u'NN')]
# VP [(u'faced', u'VBD')]
# PP [(u'as', u'IN')]
# NP [(u'a', u'DT'), (u'public', u'JJ'), (u'company', u'NN')]
# VP [(u'led', u'VBD')]
# NP [(u'Morgan', u'NNP'), (u'Stanleys', u'NNP'), (u'merger', u'NN')]
# PP [(u'in', u'IN')]
# PP [(u'with', u'IN')]
# NP [(u'the', u'DT'), (u'retail', u'JJ'), (u'brokerage', u'NN')]
# NP [(u'firm', u'JJ'), (u'Dean', u'NNP'), (u'Witter', u'NNP')]
# NP [(u'Philip', u'NNP'), (u'J.', u'NNP'), (u'Purcell', u'NNP')]
# NP [(u'a', u'DT'), (u'former', u'JJ'), (u'management', u'NN'), (u'consultant', u'NN')]
# VP [(u'had', u'VBD')]
# NP [(u'little', u'JJ'), (u'patience', u'NN')]
# PP [(u'for', u'IN')]
# NP [(u'the', u'DT'), (u'egos', u'NNS')]
# NP [(u'attitudes', u'NNS')]
# PP [(u'of', u'IN')]
# NP [(u'the', u'DT'), (u'companys', u'JJ'), (u'investment', u'NN'), (u'bankers', u'NNS')]
# VP [(u'took', u'VBD')]
# NP [(u'swift', u'NN'), (u'control', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'it', u'PRP')]
# NP [(u'the', u'DT'), (u'stage', u'NN')]
# VP [(u'was', u'VBD'), (u'set', u'VBN')]
# PP [(u'for', u'IN')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# VP [(u'was', u'VBD')]
# ADJP [(u'then', u'RB'), (u'deep', u'JJ')]
# PP [(u'in', u'IN')]
# NP [(u'retirement', u'NN')]
# VP [(u'to', u'TO'), (u'alter', u'VB')]
# NP [(u'his', u'PRP$'), (u'companys', u'JJ'), (u'destiny', u'NN')]
# ADVP [(u'again', u'RB')]
# PP [(u'In', u'IN')]
# NP [(u'he', u'PRP')]
# VP [(u'lent', u'VBD')]
# NP [(u'his', u'PRP$'), (u'name', u'NN')]
# NP [(u'reputation', u'NN'), (u'and', u'CC'), (u'finances', u'NNS')]
# NP [(u'a', u'DT'), (u'searing', u'NN'), (u'guerrilla', u'NN'), (u'war', u'NN')]
# PP [(u'albeit', u'IN')]
# VP [(u'had', u'VBD')]
# PP [(u'as', u'IN')]
# NP [(u'its', u'PRP$'), (u'headquarters', u'NN'), (u'the', u'DT'), (u'study', u'NN')]
# PP [(u'in', u'IN')]
# NP [(u'his', u'PRP$'), (u'Fifth', u'NNP'), (u'Avenue', u'NNP'), (u'apartment', u'NN')]
# NP [(u'that', u'WDT'), (u'eventually', u'RB'), (u'forced', u'JJ'), (u'Mr.', u'NNP'), (u'Purcell', u'NNP')]
# PP [(u'from', u'IN')]
# NP [(u'power', u'NN')]
# PP [(u'on', u'IN')]
# NP [(u'the', u'DT'), (u'assertion', u'NN')]
# PP [(u'that', u'IN')]
# NP [(u'his', u'PRP$'), (u'more', u'RBR'), (u'conservative', u'JJ'), (u'financial', u'JJ'), (u'approach', u'NN')]
# VP [(u'was', u'VBD'), (u'ruining', u'VBG')]
# NP [(u'Morgan', u'NNP'), (u'Stanleys', u'NNP'), (u'vaunted', u'JJ'), (u'culture', u'NN')]
# NP [(u'Parker', u'NNP')]
# VP [(u'was', u'VBD')]
# NP [(u'the', u'DT'), (u'heart', u'NN')]
# NP [(u'soul', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP')]
# VP [(u'said', u'VBD')]
# NP [(u'Anson', u'NN'), (u'M.', u'NNP'), (u'Beard', u'NNP'), (u'Jr.', u'NNP')]
# NP [(u'a', u'DT'), (u'childhood', u'NN'), (u'friend', u'NN')]
# NP [(u'colleague', u'NN')]
# VP [(u'was', u'VBD')]
# ADVP [(u'also', u'RB')]
# NP [(u'a', u'DT'), (u'member', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'a', u'DT'), (u'group', u'NN')]
# PP [(u'of', u'IN')]
# VP [(u'retired', u'VBD')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP'), (u'bankers', u'NNS')]
# VP [(u'led', u'VBD')]
# NP [(u'the', u'DT'), (u'fight', u'NN')]
# PP [(u'against', u'IN')]
# NP [(u'Mr.', u'NNP'), (u'Purcell', u'NNP')]
# NP [(u'He', u'PRP')]
# VP [(u'was', u'VBD'), (u'born', u'VBN')]
# PP [(u'into', u'IN')]
# NP [(u'the', u'DT'), (u'firm', u'NN')]
# VP [(u'became', u'VBD')]
# NP [(u'C.E.O.', u'NNP')]
# VP [(u'retired', u'VBN')]
# VP [(u'then', u'RB'), (u'brought', u'VBD')]
# PP [(u'about', u'IN')]
# NP [(u'a', u'DT'), (u'change', u'NN')]
# PP [(u'in', u'IN')]
# NP [(u'leadership', u'NN')]
# NP [(u'He', u'PRP')]
# VP [(u'was', u'VBD')]
# NP [(u'the', u'DT'), (u'firms', u'NNS'), (u'DNA', u'NNP')]
# NP [(u'Mr.', u'NNP'), (u'Beard', u'NNP')]
# VP [(u'remembered', u'VBD'), (u'calling', u'VBG')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# PP [(u'in', u'IN')]
# NP [(u'January', u'NNP')]
# VP [(u'to', u'TO'), (u'grouse', u'VBP')]
# PP [(u'that', u'IN')]
# NP [(u'the', u'DT'), (u'company', u'NN'), (u'they', u'PRP')]
# VP [(u'loved', u'VBD'), (u'was', u'VBD'), (u'changing', u'VBG')]
# PP [(u'for', u'IN')]
# ADJP [(u'worse', u'JJR')]
# PP [(u'under', u'IN')]
# NP [(u'Mr.', u'NNP'), (u'Purcell', u'NNP')]
# NP [(u'Mr.', u'NNP'), (u'Beard', u'NNP')]
# VP [(u'told', u'VBD')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# PP [(u'that', u'IN')]
# NP [(u'they', u'PRP')]
# VP [(u'had', u'VBD'), (u'to', u'TO'), (u'do', u'VB')]
# NP [(u'something', u'NN')]
# NP [(u'His', u'PRP$'), (u'response', u'NN')]
# VP [(u'was', u'VBD')]
# NP [(u'Come', u'NNP')]
# PP [(u'over', u'IN')]
# NP [(u'my', u'PRP$'), (u'apartment', u'NN')]
# NP [(u'Mr.', u'NNP'), (u'Beard', u'NNP')]
# VP [(u'recalled', u'VBD')]
# NP [(u'Two', u'CD'), (u'months', u'NNS')]
# ADVP [(u'later', u'RB')]
# NP [(u'he', u'PRP')]
# VP [(u'said', u'VBD')]
# NP [(u'they', u'PRP')]
# VP [(u'sent', u'VBD')]
# NP [(u'a', u'DT'), (u'letter', u'NN')]
# NP [(u'Mr.', u'NNP'), (u'Purcell', u'NNP')]
# VP [(u'challenging', u'VBG')]
# NP [(u'his', u'PRP$'), (u'leadership', u'NN')]
# NP [(u'He', u'PRP')]
# VP [(u'knew', u'VBD')]
# VP [(u'to', u'TO'), (u'build', u'VB')]
# NP [(u'consensus', u'NN')]
# VP [(u'get', u'VB')]
# NP [(u'things', u'NNS')]
# VP [(u'done', u'VBN')]
# NP [(u'Mr.', u'NNP'), (u'Beard', u'NNP')]
# VP [(u'said', u'VBD')]
# VP [(u'never', u'RB'), (u'would', u'MD'), (u'have', u'VB'), (u'happened', u'VBN')]
# PP [(u'without', u'IN')]
# NP [(u'Parker', u'NNP')]
# ADJP [(u'Such', u'JJ')]
# VP [(u'was', u'VBD')]
# NP [(u'Mr.', u'NNP'), (u'Gilberts', u'NNP'), (u'belief', u'NN')]
# PP [(u'in', u'IN')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP')]
# PP [(u'that', u'IN')]
# ADVP [(u'even', u'RB')]
# NP [(u'it', u'PRP')]
# VP [(u'seemed', u'VBD')]
# PP [(u'that', u'IN')]
# NP [(u'the', u'DT'), (u'company', u'NN')]
# VP [(u'could', u'MD'), (u'follow', u'VB')]
# NP [(u'Lehman', u'NNP'), (u'Brothers', u'NNPS')]
# VP [(u'go', u'VB')]
# ADJP [(u'bankrupt', u'JJ')]
# PP [(u'during', u'IN')]
# NP [(u'the', u'DT'), (u'financial', u'JJ'), (u'crisis', u'NN')]
# NP [(u'he', u'PRP')]
# VP [(u'consistently', u'RB'), (u'bought', u'VBN')]
# NP [(u'shares', u'NNS')]
# PP [(u'in', u'IN')]
# NP [(u'it', u'PRP')]
# ADVP [(u'even', u'RB')]
# PP [(u'as', u'IN')]
# NP [(u'the', u'DT'), (u'stock', u'NN'), (u'value', u'NN')]
# VP [(u'sank', u'VBD')]
# NP [(u'single', u'JJ'), (u'digits', u'NNS')]
# NP [(u'John', u'NNP'), (u'J.', u'NNP'), (u'Mack', u'NNP')]
# VP [(u'succeeded', u'VBD')]
# NP [(u'Mr.', u'NNP'), (u'Purcell', u'NNP')]
# PP [(u'as', u'IN')]
# NP [(u'chief', u'JJ'), (u'executive', u'NN')]
# PP [(u'in', u'IN')]
# VP [(u'said', u'VBD')]
# PP [(u'of', u'IN')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# PP [(u'in', u'IN')]
# NP [(u'an', u'DT'), (u'interview', u'NN')]
# NP [(u'I', u'PRP')]
# VP [(u'would', u'MD'), (u'call', u'VB')]
# NP [(u'him', u'PRP'), (u'every', u'DT'), (u'few', u'JJ'), (u'days', u'NNS')]
# PP [(u'during', u'IN')]
# NP [(u'the', u'DT'), (u'crisis', u'NN'), (u'I', u'PRP')]
# VP [(u'mean', u'VBP')]
# NP [(u'he', u'PRP')]
# VP [(u'was', u'VBD')]
# ADJP [(u'such', u'JJ')]
# NP [(u'a', u'DT'), (u'big', u'JJ'), (u'part', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP')]
# NP [(u'I', u'PRP')]
# VP [(u'just', u'RB'), (u'wanted', u'VBD')]
# NP [(u'him', u'PRP')]
# VP [(u'to', u'TO'), (u'know', u'VB')]
# VP [(u'was', u'VBD'), (u'going', u'VBG')]
# PP [(u'on', u'IN')]
# NP [(u'We', u'PRP')]
# VP [(u'were', u'VBD'), (u'really', u'RB'), (u'stressed', u'VBD')]
# PP [(u'in', u'IN')]
# NP [(u'those', u'DT'), (u'days', u'NNS')]
# NP [(u'every', u'DT'), (u'time', u'NN'), (u'I', u'PRP')]
# VP [(u'got', u'VBD')]
# PP [(u'off', u'IN')]
# NP [(u'the', u'DT'), (u'phone', u'NN')]
# PP [(u'with', u'IN')]
# NP [(u'him', u'PRP')]
# NP [(u'I', u'PRP')]
# VP [(u'would', u'MD'), (u'feel', u'VB')]
# ADJP [(u'so', u'RB'), (u'much', u'RB'), (u'better', u'JJR')]
# NP [(u'Seymour', u'NNP'), (u'Parker', u'NNP'), (u'Gilbert', u'NNP'), (u'III', u'NNP')]
# VP [(u'never', u'RB'), (u'used', u'VBD')]
# NP [(u'the', u'DT'), (u'Roman', u'NNP'), (u'numerals', u'NNS')]
# VP [(u'was', u'VBD'), (u'born', u'VBN')]
# PP [(u'in', u'IN')]
# NP [(u'New', u'NNP-LOC'), (u'York', u'NNP-LOC'), (u'City', u'NNP')]
# PP [(u'on', u'IN')]
# NP [(u'Nov', u'NNP')]
# NP [(u'His', u'PRP$'), (u'father', u'NN')]
# VP [(u'was', u'VBD')]
# NP [(u'a', u'DT'), (u'financial', u'JJ'), (u'wunderkind', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'sorts', u'NNS')]
# PP [(u'in', u'IN')]
# NP [(u'the', u'DT'), (u'years', u'NNS')]
# PP [(u'after', u'IN')]
# NP [(u'World', u'NNP'), (u'War', u'NNP'), (u'I', u'NNP')]
# VP [(u'played', u'VBD')]
# NP [(u'a', u'DT'), (u'critical', u'JJ'), (u'role', u'NN')]
# PP [(u'for', u'IN')]
# NP [(u'the', u'DT'), (u'United', u'NNP-LOC'), (u'States', u'NNPS-LOC'), (u'government', u'NN')]
# PP [(u'in', u'IN')]
# NP [(u'the', u'DT'), (u'negotiations', u'NNS')]
# PP [(u'over', u'IN')]
# NP [(u'German', u'JJ'), (u'war', u'NN'), (u'reparations', u'NNS')]
# NP [(u'Mr.', u'NNP'), (u'Gilberts', u'NNP'), (u'father', u'NN')]
# VP [(u'died', u'VBD')]
# PP [(u'at', u'IN')]
# NP [(u'his', u'PRP$'), (u'mother', u'NN')]
# VP [(u'later', u'RB'), (u'married', u'VBD')]
# NP [(u'Harold', u'NNP'), (u'Stanley', u'NNP')]
# PP [(u'after', u'IN')]
# NP [(u'the', u'DT'), (u'split', u'NN')]
# PP [(u'with', u'IN')]
# NP [(u'J.', u'NNP'), (u'P.', u'NNP'), (u'Morgan', u'NNP')]
# VP [(u'became', u'VBD')]
# NP [(u'the', u'DT'), (u'first', u'JJ'), (u'president', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP')]
# NP [(u'Mr.', u'NNP'), (u'Gilberts', u'NNP'), (u'godfather', u'NN')]
# VP [(u'was', u'VBD')]
# NP [(u'the', u'DT'), (u'firms', u'NNS')]
# NP [(u'other', u'JJ'), (u'founder', u'NN')]
# NP [(u'Henry', u'NNP'), (u'S.', u'NNP'), (u'Morgan', u'NNP')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# VP [(u'was', u'VBD'), (u'educated', u'VBN')]
# PP [(u'at', u'IN')]
# NP [(u'the', u'DT'), (u'Buckley', u'NNP'), (u'School', u'NNP')]
# NP [(u'Hotchkiss', u'NNP'), (u'and', u'CC'), (u'Yale', u'NNP')]
# PP [(u'After', u'IN')]
# NP [(u'a', u'DT'), (u'stint', u'NN')]
# PP [(u'in', u'IN')]
# NP [(u'the', u'DT'), (u'Army', u'NNP')]
# NP [(u'he', u'PRP')]
# VP [(u'joined', u'VBD')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP')]
# PP [(u'in', u'IN')]
# VP [(u'was', u'VBD')]
# NP [(u'elected', u'JJ'), (u'partner', u'NN')]
# PP [(u'in', u'IN')]
# VP [(u'Working', u'VBG')]
# ADVP [(u'primarily', u'RB')]
# PP [(u'as', u'IN')]
# NP [(u'a', u'DT'), (u'corporate', u'JJ'), (u'banker', u'NN')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# VP [(u'was', u'VBD'), (u'appointed', u'VBN'), (u'to', u'TO'), (u'lead', u'VB')]
# NP [(u'the', u'DT'), (u'firm', u'NN')]
# PP [(u'in', u'IN')]
# PP [(u'at', u'IN')]
# PP [(u'At', u'IN')]
# NP [(u'the', u'DT'), (u'time', u'NN')]
# NP [(u'Wall', u'NNP'), (u'Street', u'NNP'), (u'competitors', u'NNS')]
# PP [(u'like', u'IN')]
# NP [(u'Merrill', u'NNP'), (u'Lynch', u'NNP'), (u'and', u'CC'), (u'Bear', u'NNP'), (u'Stearns', u'NNP')]
# VP [(u'had', u'VBD'), (u'already', u'RB'), (u'gone', u'VBN')]
# NP [(u'public', u'NN')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# VP [(u'was', u'VBD'), (u'facing', u'VBG'), (u'mounting', u'VBG')]
# NP [(u'pressure', u'NN')]
# PP [(u'from', u'IN')]
# NP [(u'the', u'DT'), (u'firms', u'NNS')]
# NP [(u'younger', u'JJR'), (u'bankers', u'NNS')]
# PP [(u'for', u'IN')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP')]
# VP [(u'to', u'TO'), (u'do', u'VB')]
# ADJP [(u'same', u'JJ')]
# VP [(u'to', u'TO'), (u'compete', u'VB')]
# PP [(u'on', u'IN')]
# ADJP [(u'larger', u'JJR')]
# NP [(u'more', u'RBR'), (u'lucrative', u'JJ'), (u'banking', u'NN'), (u'deals', u'NNS')]
# NP [(u'Older', u'JJR'), (u'partners', u'NNS')]
# VP [(u'feared', u'VBD')]
# PP [(u'that', u'IN')]
# ADJP [(u'such', u'JJ')]
# NP [(u'a', u'DT'), (u'move', u'NN')]
# VP [(u'would', u'MD'), (u'have', u'VB')]
# NP [(u'a', u'DT'), (u'disastrous', u'JJ'), (u'effect', u'NN')]
# PP [(u'on', u'IN')]
# NP [(u'the', u'DT'), (u'firms', u'NNS'), (u'culture', u'NN')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# VP [(u'was', u'VBD')]
# ADJP [(u'ultimately', u'RB'), (u'able', u'JJ')]
# VP [(u'to', u'TO'), (u'make', u'VB')]
# NP [(u'the', u'DT'), (u'case', u'NN')]
# PP [(u'that', u'IN')]
# VP [(u'going', u'VBG')]
# NP [(u'public', u'NN')]
# VP [(u'was', u'VBD')]
# NP [(u'the', u'DT'), (u'right', u'JJ'), (u'thing', u'NN')]
# VP [(u'to', u'TO'), (u'do', u'VB')]
# NP [(u'the', u'DT'), (u'firm', u'NN')]
# VP [(u'did', u'VBD')]
# ADVP [(u'so', u'RB')]
# PP [(u'in', u'IN')]
# NP [(u'He', u'PRP')]
# VP [(u'retired', u'VBD')]
# PP [(u'in', u'IN')]
# NP [(u'1990', u'CD'), (u'and', u'CC'), (u'devoted', u'JJ'), (u'time', u'NN')]
# NP [(u'money', u'NN')]
# NP [(u'the', u'DT'), (u'Morgan', u'NNP'), (u'Library', u'NNP')]
# NP [(u'Museum', u'NNP')]
# NP [(u'which', u'WDT'), (u'he', u'PRP')]
# VP [(u'led', u'VBD')]
# PP [(u'from', u'IN')]
# NP [(u'He', u'PRP')]
# VP [(u'was', u'VBD')]
# ADVP [(u'also', u'RB')]
# NP [(u'a', u'DT'), (u'longtime', u'JJ'), (u'trustee', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'the', u'DT'), (u'Metropolitan', u'NNP'), (u'Museum', u'NNP')]
# PP [(u'of', u'IN')]
# NP [(u'Art.', u'NNP')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# VP [(u'lived', u'VBD')]
# PP [(u'in', u'IN')]
# NP [(u'Manhattan', u'NNP')]
# PP [(u'In', u'IN')]
# NP [(u'addition', u'NN')]
# NP [(u'his', u'PRP$'), (u'son', u'NN'), (u'S.', u'NNP'), (u'Parker', u'NNP'), (u'Jr.', u'NNP')]
# VP [(u'known', u'VBN')]
# PP [(u'as', u'IN')]
# NP [(u'Parker', u'NNP')]
# NP [(u'he', u'PRP')]
# VP [(u'is', u'VBZ'), (u'survived', u'VBN')]
# PP [(u'by', u'IN')]
# NP [(u'his', u'PRP$'), (u'wife', u'NN')]
# NP [(u'Gail', u'NNP')]
# NP [(u'a', u'DT'), (u'daughter', u'NN')]
# NP [(u'Lynn', u'NNP'), (u'Tudor', u'NNP')]
# NP [(u'another', u'DT'), (u'son', u'NN')]
# NP [(u'David', u'NNP')]
# NP [(u'a', u'DT'), (u'novelist', u'NN')]
# NP [(u'eight', u'CD'), (u'grandchildren', u'NNS')]
# PP [(u'About', u'IN')]
# NP [(u'a', u'DT'), (u'year', u'NN')]
# PP [(u'ago', u'IN')]
# NP [(u'Mr.', u'NNP'), (u'Gilbert', u'NNP')]
# VP [(u'made', u'VBD')]
# NP [(u'a', u'DT'), (u'rare', u'JJ'), (u'trip', u'NN')]
# NP [(u'Morgan', u'NNP'), (u'Stanley', u'NNP')]
# VP [(u'to', u'TO'), (u'give', u'VB')]
# NP [(u'a', u'DT'), (u'speech', u'NN')]
# NP [(u'the', u'DT'), (u'companys', u'NN')]
# VP [(u'managing', u'VBG')]
# NP [(u'directors', u'NNS')]
# PP [(u'As', u'IN')]
# VP [(u'was', u'VBD')]
# NP [(u'his', u'PRP$'), (u'style', u'NN')]
# NP [(u'his', u'PRP$'), (u'talk', u'NN')]
# VP [(u'was', u'VBD')]
# ADJP [(u'brief', u'JJ')]
# VP [(u'carried', u'VBD')]
# NP [(u'a', u'DT'), (u'powerful', u'JJ'), (u'punch', u'NN')]
# NP [(u'Morgan', u'NNP'), (u'Stanleys', u'NNP'), (u'culture', u'NN')]
# VP [(u'was', u'VBD')]
# ADVP [(u'back', u'RB')]
# NP [(u'he', u'PRP')]
# VP [(u'said', u'VBD')]
# NP [(u'a', u'DT'), (u'person', u'NN')]
# VP [(u'attended', u'VBD')]
# NP [(u'the', u'DT'), (u'event', u'NN')]
# VP [(u'recalled', u'VBN')]
# NP [(u'The', u'DT'), (u'standing', u'NN'), (u'ovation', u'NN')]
# VP [(u'lasted', u'VBD')]
# ADJP [(u'longer', u'JJR')]
# PP [(u'than', u'IN')]
# NP [(u'Mr.', u'NNP'), (u'Gilberts', u'NNP'), (u'remarks', u'NNS')]
# NP [(u'this', u'DT'), (u'person', u'NN')]
# VP [(u'said', u'VBD')]
# PP [(u'about', u'IN')]
# NP [(u'four', u'CD'), (u'minutes', u'NNS')]
# PP [(u'with', u'IN')]
# NP [(u'a', u'DT'), (u'number', u'NN')]
# PP [(u'of', u'IN')]
# NP [(u'bankers', u'NNS')]
# VP [(u'shedding', u'VBG')]
# VP [(u'tear', u'VB')]

# %%
# First step is reconjugating all the verbs to future tense
# and replacing the old verbs in the obituary
m = search('VP', s)

i = 0
j = 0
while i < len(tokens) and j < len(m):
    if m[j].string.startswith(tokens[i]):
        newVerb = conjugate(m[j].string)
        newVerbTokens = newVerb.split()
        oldVerbLen = len(m[j].string.split())
        
        if newVerbTokens[0] in ["would", "could", "to", "was"]:
            tokens[i] = newVerbTokens[0]
        else:
            tokens[i] = "will %s" % newVerbTokens[0]
        # skip punctuation tokens
        l = 1
        for k in range(2, oldVerbLen*2)[::2]:
            tokens[i+k] = newVerbTokens[l]
            l += 1
        
        i += 1
        j += 1
    else:
        i += 1

newText = "".join(tokens)

newText = re.sub(r"\bhad\b", "have", newText)

# Update years

years = re.findall(r"\b[0-9]{4}\b", newText)

for year in years:
    newText.replace(year, str(int(year)+20))
    
# Change name and personal pronouns

newText = re.sub(r"\bshe\b|\bhe\b", "you", newText, flags=re.IGNORECASE)
newText = re.sub(r"\bher\b|\bhis\b", "your", newText, flags=re.IGNORECASE)

obitName = match('NP', s).string # Assuming that deceased's name will be first noun phrase!
obitNameTokens = obitName.split()

obitTitle = "(Mr.|Mrs.|Ms.) " + obitNameTokens[-1]

newText = re.sub(obitName, "you", newText)
newText = re.sub(obitTitle, "you", newText)

# capitalize sentences...

newText = list(newText)

newText[0] = newText[0].upper()

for i in range(2, len(newText)):
    if newText[i-1] == '\n' or newText[i-2] == '.':
        newText[i] = newText[i].upper()
        
newText = ''.join(newText)

print newText
# Out:
# You, a former chairman of Morgan Stanley who will lead its public stock offering in 1986 and will organize a management revolt at that storied investment house 20 years later, will die on Wednesday in Manhattan. You will be 81.
#
# Your son Parker will say that you will have been treat for chronic obstructive pulmonary disease for years and that you will die at NewYork-Presbyterian Hospital.
#
# You will be a stepson and a godson of Morgan Stanleys founders, and you will come of age on Wall Street when family name and pedigree will be often enough to land one will also play at the elite partnerships of the day, like Morgan Stanley and Goldman Sachs.
#
# But you also played a role in will explode this cozy world when you will unite a will divide body of Morgan Stanley bankers behind the idea that the firm could grow and will prosper only if it will sell shares to the public.
#
# That will move, and the subsequent pressures that the business will face as a public company, will lead to Morgan Stanleys merger in 1997 with the retail brokerage firm Dean Witter.
#
# And when Philip J. Purcell, a former management consultant who will have little patience for the egos and attitudes of the companys investment bankers, will take swift control of it, the stage was set for you  who will be then deep in retirement  to alter your companys destiny again.
#
# In 2005, you will lend your name, reputation and finances to a searing guerrilla war (albeit one that will have as its headquarters the study in your Fifth Avenue apartment) that eventually forced Mr. Purcell from power on the assertion that your more conservative financial approach was ruine Morgan Stanleys vaunted culture.
#
# Parker will be the heart and soul of Morgan Stanley, will say Anson M. Beard Jr., a childhood friend and colleague who will be also a member of a group of eight will retire Morgan Stanley bankers who will lead the fight against Mr. Purcell. You was born into the firm, will become C.E.O., will retire and will then brought about a change in leadership. You will be the firms DNA.
#
# Mr. Beard will remembered cal you in January 2005 to grouse that the company they will loved was change for the worse under Mr. Purcell. Mr. Beard will tell you that they will have to do something.
#
# Your response will be, Come over to my apartment,  Mr. Beard will recall. Two months later, you will say, they will send a letter to Mr. Purcell will challenge your leadership.
#
# You will know how to build consensus and will get things will do, Mr. Beard will say. This will never would have happen without Parker.
#
# Such will be yous belief in Morgan Stanley that even when it will seem that the company could follow Lehman Brothers and will go bankrupt during the financial crisis, you will consistently bought shares in it, even as the stock value will sank to single digits.
#
# John J. Mack, who will succeed Mr. Purcell as chief executive in 2005, will say of you in an interview: I would call him every few days during the crisis  I will mean, you will be such a big part of Morgan Stanley, I will just want him to know what was go on. We will were really stress in those days, but every time I will get off the phone with him, I would feel so much better.
#
# Seymour Parker Gilbert III (who will never use the Roman numerals) was born in New York City on Nov. 15, 1933. Your father will be a financial wunderkind of sorts who in the years after World War I will play a critical role for the United States government in the negotiations over German war reparations.
#
# Yous father will die at 45, and your mother will later marry Harold Stanley, who after the split with J. P. Morgan will become the first president of Morgan Stanley. Yous godfather will be the firms other founder, Henry S. Morgan.
#
# You was educate at the Buckley School, Hotchkiss and Yale. After a stint in the Army, you will join Morgan Stanley in 1960 and will be elected partner in 1969.
#
# Will work primarily as a corporate banker, you was appointed to lead the firm in 1984 at 49.
#
# At the time, Wall Street competitors like Merrill Lynch and Bear Stearns will have already gone public, and you was facing mount pressure from the firms younger bankers for Morgan Stanley to do the same to compete on larger, more lucrative banking deals.
#
# Older partners will fear that such a move would have a disastrous effect on the firms culture.
#
# You will be ultimately able to make the case that will go public will be the right thing to do, and the firm will do so in 1986.
#
# You will retire in 1990 and devoted time and money to the Morgan Library and Museum, which you will lead from 1988 to 2011. You will be also a longtime trustee of the Metropolitan Museum of Art.
#
# You will live in Manhattan. In addition to your son S. Parker Jr., will know as Parker, you will is survive by your wife, Gail; a daughter, Lynn Tudor; another son, David, a novelist; and eight grandchildren.
#
# About a year ago, you will make a rare trip to give Stanley to give a speech to the companys will manage directors.
#
# As will be your style, your talk will be brief but will carry a powerful punch: Morgan Stanleys culture will be back, you will say, will attend person who attended the event will recall.
#
# The standing ovation will last longer than yous remarks, this person will say: about four minutes, with a number of bankers will shed a will tear or two.
